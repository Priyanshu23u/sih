# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("news_data.csv")

# Define the list of crime-related keywords
disaster_keywords = {
    'earthquake': 'Earthquake', 
    'flood': 'Flood', 
    'tsunami': 'Tsunami', 
    'hurricane': 'Hurricane', 
    'tornado': 'Tornado', 
    'wildfire': 'Wildfire',
    'landslide': 'Landslide', 
    'volcano': 'Volcanic Eruption', 
    'drought': 'Drought', 
    'cyclone': 'Cyclone', 
    'storm': 'Storm', 
    'avalanche': 'Avalanche', 
    'blizzard': 'Blizzard',
    'heatwave': 'Heatwave', 
    'hailstorm': 'Hailstorm', 
    'mudslide': 'Mudslide', 
    'famine': 'Famine', 
    'pandemic': 'Pandemic', 
    'outbreak': 'Outbreak',
    'snowstorm': 'Snowstorm', 
    'sandstorm': 'Sandstorm', 
    'disaster': 'Disaster', 
    'natural disaster': 'Natural Disaster', 
    'calamity': 'Calamity', 
    'emergency': 'Emergency',
    'hazard': 'Hazard', 
    'catastrophe': 'Catastrophe', 
    'rescue': 'Rescue Operation',
    'relief': 'Relief Effort',
    'evacuation': 'Evacuation',
    'debris': 'Debris',
    'tsunami warning': 'Tsunami Warning',
    'aftershock': 'Aftershock',
    'lightening':'lightening',
}

# Function to label data based on keywords
def label_data(title):
    for keyword in disaster_keywords:
        if keyword in title.lower():
            return 1  
    return 0  


# Apply the functions to the dataset
df['label'] = df['Title'].apply(label_data)
df.to_csv('ans.csv', index=False)

# Drop duplicates

# %%
df = df.drop_duplicates()

# Filter for rows with crime-related titles
df_zero_label = df[df['label'] == 1]

# Save the new dataset with crime type detection
df.to_csv('ans1.csv', index=False)

# Display the result
print(df_zero_label)
# Out:
#                                                  Title  \
# 57   How Trackman's Alertness Averted Major Train D...
# 193  Chennai artist honours Wayanad landslide survi...
# 211  Low pressure in Bay of Bengal to bring more ra...
# 331   Budameru Breaches Plugged, Flood Inflows to V...
# 679   BJP's Jairam Thakur Trapped In Himachal's Ban...
# 686  Caste Census Controversy: Digvijaya Singh's 'N...
# 687  Manipur Is Tense Again! 5 Killed In Violence, ...
# 780  Resumption Of Water & Electricity Supply, Reli...
# 782  Hyderabad Weather Today: City On Yellow Alert,...
# 789   In Chennai Schools, Maha Vishnu Talked About ...
# 873  Ahmedabad Braces for Light Rain and Cloudy Ski...
# 874  Ahmedabad Cyclone Asna HIGHLIGHTS: Cyclone Asn...
# 879  Vadodara Rains: Drone Video Captures City In F...
# 880  'Flash Flood Risk' in Ahmedabad And Other Citi...
# 896  BJP's Jairam Thakur Trapped In Himachal's Band...
# 910  Himachal Rain: Shimla, Solan And Sirmaur Under...
